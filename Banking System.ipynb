# %% [markdown]
# Banking System

# %%
class BankAccount:
    
    bank_name = "Secure Python Bank"
    
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited {amount}")
        else:
            print("Invalid deposit amount")
            
    # ✅ Withdraw method correctly inside class
    def withdraw(self, amount):
        if amount <= 0:
            print("Invalid withdrawal amount")
        elif amount > self.__balance:
            print("Insufficient balance")
        else:
            self.__balance -= amount
            print(f"Withdrew {amount}")
    @property
    def balance(self):
        return self.__balance

    @classmethod
    def bank_info(cls):
        return f"Welcome to {cls.bank_name}"

    @staticmethod
    def validate_amount(amount):
        return amount > 0

    def __str__(self):
        return f"Account Owner: {self.owner} | Balance: {self.__balance}"

# %% [markdown]
# Create Account Object

# %%
account1 = BankAccount("Nisha", 1000)

# %% [markdown]
# Deposit Money

# %%
account1.deposit(500)
# Out:
# Deposited 500

# %% [markdown]
# withdraw money

# %% [markdown]
# Check balance

# %%
account1.withdraw(300)
# Out:
# Withdrew 300

# %% [markdown]
# Account Summary

# %%
print(account1)
# Out:
# Account Owner: Nisha | Balance: 900

# %%
BankAccount.bank_info()
# Out:
# 'Welcome to Secure Python Bank'

# %% [markdown]
# Static Method Test

# %%
BankAccount.validate_amount(100)
# Out:
# True
